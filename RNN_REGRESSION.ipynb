# %% [markdown]
# ## RNN REGRESSION
#  STEPS
# 1. Load data
# 2. Build model
# 3. Train model
# 4. Test model

# %% [markdown]
# # Many-to-one

# %%
from IPython.display import Image
Image(filename="/src/keras/Gerome/01_main/95_keras_practice/many_to_one.png", height=200, width=200)

# %% [markdown]
# * single scalar output value
# * input_x.shape == (batch_size, timesteps, n_dims)
# * target_y.shape == (batch_size, 1)

# %% [markdown]
# ## 1. Load Data

# %% [markdown]
# ## 2. Build Model

# %%
model_classification = Sequential()
model_classification.add(GRU(hidden_units,
               input_shape=input_shape))
model_classification.add(Dense(1, activation='linear'))
model_classification.compile(loss='mean_squared_error', optimizer='sgd')

# %% [markdown]
# ## 3. Train Model

# %% [markdown]
# ## 4. Evaluate Model

# %% [markdown]
# # Many-to-many

# %%
Image(filename="/src/keras/Gerome/01_main/95_keras_practice/many_to_many.png", height=200, width=200)

# %% [markdown]
# * single scalar output value for every timestep
# * input_x.shape == (batch_size, timesteps, n_dims)
# * target_y.shape == (batch_size, timesteps, 1)

# %% [markdown]
# ## 1. Load Data

# %% [markdown]
# ## 2. Build Model

# %%
model_c_many = Sequential()
model_c_many.add(LSTM(hidden_units,
               input_shape=input_shape,
                             return_sequences=True))
model_c_many.add(TimeDistributed(Dense(1, activation='linear')))
model_c_many.compile(loss='mse', optimizer='RMSprop')

# %% [markdown]
# ## 3. Train Model

# %% [markdown]
# ## 4. Evaluate Model
